# %%
#==========================================
#PERTEMUAN 1 = Notbook Pertama Data Science
#==========================================

# Sel 1  : output sederhana
print ("Hallo, Data Science!")
print ("Selamat datang di matakuliah Data Science!")


# Sel 2  : variabel dan tipe data dasar
nama        = "Angga Anggieanie"         #string
angkatan    = 2026                       #Integer
ipk         = 3.80                       #Float
aktif       = True                       #Boolean

print(F"Nama          : {nama}")
print(F"Angkatan      : {angkatan}")
print(F"IPK           : {ipk}")
print(F"Aktif         : {aktif}")

# Sel 3  : List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print ("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
    print(f"  {i}. {tool}")

# Sel 4  : Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Saya {'Angga Anggieanie'} dari {'PJJ INFORMATIKA'}, angkatan {2025}."

hasil = perkenalan("Angga Anggieanie", "Informatika", 2026)
print(hasil)

 #catatan belajar data Science
 #SEL 1: Output sederhana
 #print() digunakan untuk menampilkan teks ke layar.

 #SEL 2: Variabel dan tipe data dasar
 #String --> teks ("Angga Anggieanie")
 #Integer ---> bilangan bulat (2025)
 #Float ----> bilangan desimal (3.80)
 #Boolean -----> nilai benar/salah (True / False)
 #f-string -----> exmple (f"Nama {nama}) digunakan untuk menyisipkan variabel ke dalam string dengan oprator kurung kurawa {}

 #SEL 3: List dan perulangan
 #for --> untuk perulangan
 #enumerate() ---> memberi nomor urut
 # , 1 ----> Mulai dari angka 1

 # SEL 4: Fungsi sederhana
 #def digunakan untuk membuat fungsi latihan di atas membuat 3 fungsi parameter yaitu --> nama, prodi, dan angkatan
 #return mengembalikan nilai dari fungsi

 ##kesimpulan Hand-on dari kode python dasar di atas yaitu
##Output (print)
##Variabel & tipe data
##List
##Perulangan (for)
##Fungsi (def)

#===========di bawa ini hasil output=================
# Out:
# Hallo, Data Science!
# Selamat datang di matakuliah Data Science!
# Nama          : Angga Anggieanie
# Angkatan      : 2026
# IPK           : 3.8
# Aktif         : True
#
# Tools Data Science yang akan kita pelajari:
#   1. Python
#   2. Google Colab
#   3. Jupyter Notebook
#   4. GitHub
# Hai! Saya Angga Anggieanie dari PJJ INFORMATIKA, angkatan 2025.
